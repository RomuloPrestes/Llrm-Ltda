# %% [markdown]
# <a href="https://colab.research.google.com/github/RomuloPrestes/Llrm-Ltda/blob/main/cortes_da_imagem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importação das bibliotecas
import cv2
import glob
import matplotlib.pyplot as plt
import math

# %%
#Leitura das imagens
imagefiles = glob.glob("/content/drive/MyDrive/Bio System Ltda/Banco de dados/imagem editada/20221113_170703 sem fundo.png")
imagefiles.sort()

images = []
for filename in imagefiles:
  img = cv2.imread(filename)
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  images.append(img)

num_images = len(images)

# %%
#Exibição das imagens
plt.figure(figsize=[30,10]) 
num_cols = 3
num_rows = math.ceil(num_images / num_cols)
for i in range(0, num_images):
  plt.subplot(num_rows, num_cols, i+1) 
  plt.axis('off')
  plt.imshow(images[i])

# %%
#Construção do mosaico e exibição do resultado
stitcher = cv2.Stitcher_create()
status, result = stitcher.stitch(images)
if status == 0:
  plt.figure(figsize=[30, 10])
  plt.imshow(result)
  plt.show()
